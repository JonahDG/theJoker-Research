# %%
# imports
# !pip install lightkurve
# !pip install fpdf
# !pip install thejoker
from astropy.io import ascii
from astropy.io import fits
from astropy import units as u
import astropy.table as at
from astropy.time import Time
import astropy.coordinates as coords 
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import lightkurve as lk
from fpdf import FPDF
import thejoker as tj
from astropy.timeseries import LombScargle
# Out:
# Requirement already satisfied: lightkurve in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (2.1.0)
# Requirement already satisfied: astroquery>=0.3.10 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from lightkurve) (0.4.5)
# Requirement already satisfied: matplotlib>=3.1 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from lightkurve) (3.4.3)
# Requirement already satisfied: numpy>=1.18 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from lightkurve) (1.20.3)
# Requirement already satisfied: scipy>=1.7 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from lightkurve) (1.7.1)
# Requirement already satisfied: bokeh>=1.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from lightkurve) (2.4.1)
# Requirement already satisfied: uncertainties>=3.1.4 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from lightkurve) (3.1.6)
# Requirement already satisfied: tqdm>=4.25.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from lightkurve) (4.62.3)
# Requirement already satisfied: oktopus>=0.1.2 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from lightkurve) (0.1.2)
# Requirement already satisfied: patsy>=0.5.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from lightkurve) (0.5.2)
# Requirement already satisfied: astropy>=5.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from lightkurve) (5.0.1)
# Requirement already satisfied: requests>=2.22.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from lightkurve) (2.26.0)
# Requirement already satisfied: fbpca>=1.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from lightkurve) (1.0)
# Requirement already satisfied: pandas>=1.1.4 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from lightkurve) (1.3.4)
# Requirement already satisfied: beautifulsoup4>=4.6.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from lightkurve) (4.10.0)
# Requirement already satisfied: memoization>=0.3.1 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from lightkurve) (0.4.0)
# Requirement already satisfied: scikit-learn>=0.24.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from lightkurve) (0.24.2)
# Requirement already satisfied: urllib3>=1.23 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from lightkurve) (1.26.7)
# Requirement already satisfied: PyYAML>=3.13 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from astropy>=5.0->lightkurve) (6.0)
# Requirement already satisfied: pyerfa>=2.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from astropy>=5.0->lightkurve) (2.0.0)
# Requirement already satisfied: packaging>=19.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from astropy>=5.0->lightkurve) (21.0)
# Requirement already satisfied: html5lib>=0.999 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from astroquery>=0.3.10->lightkurve) (1.1)
# Requirement already satisfied: keyring>=4.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from astroquery>=0.3.10->lightkurve) (23.1.0)
# Requirement already satisfied: pyvo>=1.1 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from astroquery>=0.3.10->lightkurve) (1.2.1)
# Requirement already satisfied: soupsieve>1.2 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4>=4.6.0->lightkurve) (2.2.1)
# Requirement already satisfied: pillow>=7.1.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from bokeh>=1.0->lightkurve) (8.4.0)
# Requirement already satisfied: Jinja2>=2.9 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from bokeh>=1.0->lightkurve) (2.11.3)
# Requirement already satisfied: typing-extensions>=3.10.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from bokeh>=1.0->lightkurve) (3.10.0.2)
# Requirement already satisfied: tornado>=5.1 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from bokeh>=1.0->lightkurve) (6.1)
# Requirement already satisfied: webencodings in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from html5lib>=0.999->astroquery>=0.3.10->lightkurve) (0.5.1)
# Requirement already satisfied: six>=1.9 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from html5lib>=0.999->astroquery>=0.3.10->lightkurve) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from Jinja2>=2.9->bokeh>=1.0->lightkurve) (1.1.1)
# Requirement already satisfied: importlib-metadata>=3.6 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from keyring>=4.0->astroquery>=0.3.10->lightkurve) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=3.6->keyring>=4.0->astroquery>=0.3.10->lightkurve) (3.6.0)
# Requirement already satisfied: cycler>=0.10 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1->lightkurve) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1->lightkurve) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1->lightkurve) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.1->lightkurve) (2.8.2)
# Requirement already satisfied: autograd in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from oktopus>=0.1.2->lightkurve) (1.3)
# Requirement already satisfied: pytz>=2017.3 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.1.4->lightkurve) (2021.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.22.0->lightkurve) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.22.0->lightkurve) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.22.0->lightkurve) (2.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.24.0->lightkurve) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.24.0->lightkurve) (1.1.0)
# Requirement already satisfied: future in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from uncertainties>=3.1.4->lightkurve) (0.18.2)
# Collecting fpdf
#   Downloading fpdf-1.7.2.tar.gz (39 kB)
# Building wheels for collected packages: fpdf
#   Building wheel for fpdf (setup.py) ... done
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40722 sha256=3d6113d33833334d0c888d5280ece15e1d5569f22e17de657120ccc4dcf9ec4a
#   Stored in directory: /Users/jonahgoldfine/Library/Caches/pip/wheels/44/35/8b/86ce00cec7e4d13c5f189680ae0fa82f919bedc066c2cddae9
# Successfully built fpdf
# Installing collected packages: fpdf
# Successfully installed fpdf-1.7.2
# Requirement already satisfied: thejoker in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (1.0)
# Requirement already satisfied: tables in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from thejoker) (3.6.1)
# Requirement already satisfied: twobody>=0.5 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from thejoker) (0.8.3.dev1+g2c2750e)
# Requirement already satisfied: astropy in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from thejoker) (5.0.1)
# Requirement already satisfied: schwimmbad in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from thejoker) (0.3.2)
# Requirement already satisfied: h5py>=2.9 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from thejoker) (3.2.1)
# Requirement already satisfied: scipy in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from thejoker) (1.7.1)
# Requirement already satisfied: pymc3>=3.7 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from thejoker) (3.11.4)
# Requirement already satisfied: exoplanet>=0.2.2 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from thejoker) (0.5.2)
# Requirement already satisfied: aesara-theano-fallback>=0.0.2 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from exoplanet>=0.2.2->thejoker) (0.1.0)
# Requirement already satisfied: exoplanet-core>=0.1 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from exoplanet>=0.2.2->thejoker) (0.1.2)
# Requirement already satisfied: pyerfa>=2.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from astropy->thejoker) (2.0.0)
# Requirement already satisfied: PyYAML>=3.13 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from astropy->thejoker) (6.0)
# Requirement already satisfied: numpy>=1.18 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from astropy->thejoker) (1.20.3)
# Requirement already satisfied: packaging>=19.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from astropy->thejoker) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from packaging>=19.0->astropy->thejoker) (3.0.4)
# Requirement already satisfied: cachetools>=4.2.1 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from pymc3>=3.7->thejoker) (5.0.0)
# Requirement already satisfied: pandas>=0.24.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from pymc3>=3.7->thejoker) (1.3.4)
# Requirement already satisfied: typing-extensions>=3.7.4 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from pymc3>=3.7->thejoker) (3.10.0.2)
# Requirement already satisfied: fastprogress>=0.2.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from pymc3>=3.7->thejoker) (1.0.2)
# Requirement already satisfied: dill in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from pymc3>=3.7->thejoker) (0.3.4)
# Requirement already satisfied: arviz>=0.11.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from pymc3>=3.7->thejoker) (0.11.4)
# Requirement already satisfied: theano-pymc==1.1.2 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from pymc3>=3.7->thejoker) (1.1.2)
# Requirement already satisfied: semver>=2.13.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from pymc3>=3.7->thejoker) (2.13.0)
# Requirement already satisfied: patsy>=0.5.1 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from pymc3>=3.7->thejoker) (0.5.2)
# Requirement already satisfied: filelock in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from theano-pymc==1.1.2->pymc3>=3.7->thejoker) (3.3.1)
# Requirement already satisfied: netcdf4 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from arviz>=0.11.0->pymc3>=3.7->thejoker) (1.5.8)
# Requirement already satisfied: matplotlib>=3.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from arviz>=0.11.0->pymc3>=3.7->thejoker) (3.4.3)
# Requirement already satisfied: xarray>=0.16.1 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from arviz>=0.11.0->pymc3>=3.7->thejoker) (0.21.1)
# Requirement already satisfied: setuptools>=38.4 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from arviz>=0.11.0->pymc3>=3.7->thejoker) (58.0.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3>=3.7->thejoker) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3>=3.7->thejoker) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3>=3.7->thejoker) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0->arviz>=0.11.0->pymc3>=3.7->thejoker) (2.8.2)
# Requirement already satisfied: six in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=3.0->arviz>=0.11.0->pymc3>=3.7->thejoker) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.24.0->pymc3>=3.7->thejoker) (2021.3)
# Requirement already satisfied: cftime in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from netcdf4->arviz>=0.11.0->pymc3>=3.7->thejoker) (1.5.2)
# Requirement already satisfied: numexpr>=2.6.2 in /Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages (from tables->thejoker) (2.7.3)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/twobody/anomaly.py in <module>
#       6 try:
# ----> 7     from astropy.utils import wraps
#       8 except ImportError:
#
# ImportError: cannot import name 'wraps' from 'astropy.utils' (/Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages/astropy/utils/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /var/folders/gp/tcqhw2_d0pd5bc11n74f4whw0000gn/T/ipykernel_9546/624859807.py in <module>
#      14 import lightkurve as lk
#      15 from fpdf import FPDF
# ---> 16 import thejoker as tj
#      17 from astropy.timeseries import LombScargle
#
# ~/opt/anaconda3/lib/python3.9/site-packages/thejoker/__init__.py in <module>
#       4 # For egg_info test builds to pass, put package imports here.
#       5 if not _ASTROPY_SETUP_:  # noqa
# ----> 6     from .thejoker import TheJoker
#       7     from .data import RVData
#       8     from .samples import JokerSamples
#
# ~/opt/anaconda3/lib/python3.9/site-packages/thejoker/thejoker.py in <module>
#      11 from .likelihood_helpers import get_trend_design_matrix
#      12 from .prior_helpers import validate_n_offsets, validate_poly_trend
# ---> 13 from .prior import JokerPrior, _validate_model
#      14 from .src.fast_likelihood import CJokerHelper
#      15 from .utils import tempfile_decorator
#
# ~/opt/anaconda3/lib/python3.9/site-packages/thejoker/prior.py in <module>
#       6 # Project
#       7 from .logging import logger
# ----> 8 from .samples import JokerSamples
#       9 from .prior_helpers import (get_nonlinear_equiv_units,
#      10                             get_linear_equiv_units,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/thejoker/samples.py in <module>
#       8 from astropy.table import Table, QTable, Row, meta, serialize
#       9 import numpy as np
# ---> 10 from twobody import KeplerOrbit, PolynomialRVTrend
#      11
#      12 # Project
#
# ~/opt/anaconda3/lib/python3.9/site-packages/twobody/__init__.py in <module>
#      26
#      27 if not _ASTROPY_SETUP_:
# ---> 28     from .anomaly import *
#      29     from .barycenter import *
#      30     from .bary_trends import *
#
# ~/opt/anaconda3/lib/python3.9/site-packages/twobody/anomaly.py in <module>
#       7     from astropy.utils import wraps
#       8 except ImportError:
# ----> 9     from astropy.utils.decorators import wraps
#      10
#      11 # Project
#
# ImportError: cannot import name 'wraps' from 'astropy.utils.decorators' (/Users/jonahgoldfine/opt/anaconda3/lib/python3.9/site-packages/astropy/utils/decorators.py)

# %%
def getStarData(apogeeFileName,tessFileName,binariesFile):
  # APOGEE Visits Data
  apogeeVisits=at.Table.read(apogeeFileName) # import file
  # Binary Catalog
  binaries=at.QTable.read(binariesFile) # import file
  # Tess Data
  tessData=at.QTable.read(tessFileName) # import file
  tessData=tessData[tessData['separation']<2.*u.arcsec] # separation Filter
  # join tables
  sources=at.join(binaries,tessData,keys='APOGEE_ID')
  sources=sources[0:5]
  return apogeeVisits, sources

# %%
def getJokerRVData(allVisits,sources):
  data=[]
  for row in sources:
    visits=allVisits[allVisits['APOGEE_ID']==row['APOGEE_ID']]
    datum=tj.RVData(Time(visits['JD'],format='jd'),
                    rv=visits['VHELIO']*u.km/u.s,
                    rv_err=visits['VRELERR']*u.km/u.s)
    data.append(datum)
  return data

# %%
def getLightCurveData(sources):
  ticList=[]
  timeList=[]
  fluxList=[]
  fluxErrList=[]
  for tic in sources['TICID']:
    ticStr='TIC'+str(tic)
    ticList.append(ticStr)
    print(ticStr)
    try:
      lcCollection=lk.search_lightcurve(target=ticStr,mission='TESS').download_all()
      lcStitch=lcCollection.stitch()
      time=lcStitch.time.value
      flux=1e3*(lcStitch.flux-1)
      fluxErr=1e3*(lcStitch.flux_err)
      time=np.ascontiguousarray(time)
      flux=np.ascontiguousarray(flux,dtype=np.float64)
      timeList.append(time)
      fluxList.append(flux)
      fluxErrList.append(fluxErr)
    except: #still having that weird bug with lightkurve hopefully this works as a temporary fix
      print('Probably MergeConflictError and/or TableMergeError')
      timeList.append([])
      fluxList.append([])
      fluxErrList.append([])
      pass
    lcDataTable=at.QTable([ticList,timeList,fluxList,fluxErrList],names=('TICID',
                                                                       'Time',
                                                                       'Flux',
                                                                       'Flux_err'))
  return lcDataTable

# %%
def getLsPeriodogram(sources):
  freqList=[]
  powList=[]
  lcData=getLightCurveData(sources)
  for i in range(len(sources['MAP_P'])):
    period=int(sources[i]['MAP_P']/u.d)
    timeViaLC=lcData[i]['Time']
    fluxViaLC=lcData[i]['Flux']
    freq,pow=LombScargle(timeViaLC,fluxViaLC).autopower(minimum_frequency=(.1/period),maximum_frequency=(10./period))
    freqList.append(freq)
    powList.append(pow)
  periodogramDataTable=at.QTable([freqList,powList],names=('Frequency','Power'))
  return periodogramDataTable

# %%
def getPlots(sources,jData,periodogram,joker,prior_sample):
  pdf=FPDF(unit='in',format=[8.5,11])
  for i in range(len(sources['APOGEE_ID'])):
    # Titles
    supTitle='APOGEE ID: '+str(sources[i]['APOGEE_ID']+' | TIC ID: TIC'+str(sources[i]['TICID']))
    plot1Title='Eccentricity vs Period'
    plot2Title='Lomb Scargle Periodogram'
    # Figure Creation
    fig,(ax1,ax2)=plt.subplots(nrows=2,ncols=1,figsize=(20,10),facecolor='w')
    fig.suptitle(supTitle)
    # plot 1
    sample=joker.rejection_sample(jData[i],prior_sample)
    ax1.plot(sample['P'],sample['e'],'k.')
    ax1.set_xlabel('Period (d)')
    ax1.set_ylabel('Eccentricity')
    ax1.set_title(plot1Title)
    # Plot 2
    freq=periodogram[i]['Frequency']
    pow=periodogram[i]['Power']
    ax2.plot(freq,pow)
    ax2.set_xlabel('Frequency (1/d)')
    ax2.set_ylabel('Power')
    ax2.set_title(plot2Title)

    # save figure
    pngPath='/content/drive/MyDrive/Colab Notebooks/Research/theJoker/FvP-PvE-Plots/Individual Plots/Periodogram_EccenPeriod_'+str(sources[i]['APOGEE_ID'])+'.png'
    fig.savefig(pngPath,dpi=150)
    pdf.add_page()
    pdf.image(pngPath,w=8,h=9.6)
    print(supTitle+'DONE')
  pdf.output('/content/drive/MyDrive/Colab Notebooks/Research/theJoker/FvP-PvE-Plots/All_Periodogram_EccenPeriod_Plots.pdf','F')
  print('PLOTS SAVED AS PDF')

# %%
apogeeFile='/content/drive/MyDrive/Colab Notebooks/Research/theJoker/Data/allVisit-r12-l33.fits'
tessFile='/content/drive/MyDrive/Colab Notebooks/Research/theJoker/Data/allStarLite-r12-l33-tess_2min-max_20arcsec-xm.fits'
binaryMetadataFile='/content/drive/MyDrive/Colab Notebooks/Research/theJoker/Data/metadata.fits'
apogeeData,sourceData=getStarData(apogeeFile,tessFile,binaryMetadataFile)
jokerRVData=getJokerRVData(apogeeData,sourceData)
lsPeriodogramData=getLsPeriodogram(sourceData)
# prior=tj.JokerPrior.default(P_min=0.2*u.day,P_max=25*u.day,sigma_K0=300*u.km/u.s,sigma_v=100*u.km/u.s)
# joker=tj.TheJoker(prior)
# priorSample=prior.sample(100_00)
# Out:
# TIC388602672
# /usr/local/lib/python3.7/dist-packages/lightkurve/collections.py:214: LightkurveWarning: The following columns will be excluded from stitching because the column types are incompatible: {'sap_bkg_err', 'sap_bkg', 'sap_flux'}
#   LightkurveWarning,
# TIC257487686
# /usr/local/lib/python3.7/dist-packages/astropy/units/quantity.py:378: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   subok=True, ndmin=ndmin)
# TIC257501815
# /usr/local/lib/python3.7/dist-packages/astropy/units/quantity.py:378: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   subok=True, ndmin=ndmin)
# TIC257501838
# /usr/local/lib/python3.7/dist-packages/astropy/units/quantity.py:378: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   subok=True, ndmin=ndmin)
# TIC293219556
# /usr/local/lib/python3.7/dist-packages/astropy/units/quantity.py:378: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   subok=True, ndmin=ndmin)

# %%
getPlots(sourceData,jokerRVData,lsPeriodogramData,joker,priorSample)
# Out:
# APOGEE ID: 2M00014989+8003031 | TIC ID: TIC388602672DONE
# APOGEE ID: 2M00015793+0007429 | TIC ID: TIC257487686DONE
# APOGEE ID: 2M00020618+0030136 | TIC ID: TIC257501815DONE
# APOGEE ID: 2M00020648+0024553 | TIC ID: TIC257501838DONE
# APOGEE ID: 2M00055366+0032349 | TIC ID: TIC293219556DONE
# PLOTS SAVED AS PDF

# %%
# print(len(apogeeData))
# print(len(sourceData))
# print(apogeeData.info)
print(sourceData.info)
# print(sourceData)
# lcData=getLightCurveData(sourceData)
# print(sourceData[0]['MAP_P']/u.d)
# print(lsPeriodogramData['Frequency'])
# print(lsPeriodogramData['Power'])
# Out:
# <QTable length=5>
#               name                dtype   unit     class     n_bad
# -------------------------------- ------- ------ ------------ -----
#                        APOGEE_ID bytes18              Column     0
#                         n_visits   int64        MaskedColumn     0
#                            MAP_P float64      d     Quantity     0
#                        MAP_P_err float64      d     Quantity     5
#                            MAP_e float64            Quantity     0
#                        MAP_e_err float64            Quantity     5
#                        MAP_omega float64    rad     Quantity     0
#                    MAP_omega_err float64    rad     Quantity     5
#                           MAP_M0 float64    rad     Quantity     0
#                       MAP_M0_err float64    rad     Quantity     5
#                            MAP_K float64 km / s     Quantity     0
#                        MAP_K_err float64 km / s     Quantity     5
#                           MAP_v0 float64 km / s     Quantity     0
#                       MAP_v0_err float64 km / s     Quantity     5
#                            MAP_s float64 km / s     Quantity     0
#                        MAP_s_err float64 km / s     Quantity     5
#                          t0_bmjd float64              Column     0
#                         baseline float64      d     Quantity     0
#                MAP_ln_likelihood float64            Quantity     0
#                     MAP_ln_prior float64            Quantity     0
# max_unmarginalized_ln_likelihood float64              Column     0
#                    max_phase_gap float64            Quantity     0
#                  periods_spanned float64              Column     0
#                   phase_coverage float64              Column     0
#        phase_coverage_per_period   int64        MaskedColumn     0
#                         unimodal    bool              Column     0
#                  joker_completed    bool              Column     0
#                   mcmc_completed    bool              Column     0
#                     mcmc_success    bool              Column     0
#                 gelman_rubin_max float64        MaskedColumn     5
#           constant_ln_likelihood float64              Column     0
#    robust_constant_ln_likelihood float64              Column     0
#                   binary_catalog    bool              Column     0
#                            TICID   int64              Column     0
#                       separation float64    deg        Angle     0
